# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from quam_libs.lib.save_utils import load_dataset
# Out:
# 2024-10-28 21:04:25,957 - qm - INFO     - Starting session: 0d59bf1b-c69c-4b72-914f-2cc3c13e0d14

# %%
meas_ids = [1985,1990,1995,2000,2005]

datas = {}
node_parameters = {}
machines = {}
gains = {}  

for meas_id in meas_ids:
    datas[meas_id], machines[meas_id], node_parameters[meas_id] = load_dataset(meas_id, "noise_spectrum")
    gains[meas_id] = machines[meas_id].qubits[node_parameters[meas_id]['initial_parameters']['qubits'][0]].resonator.frequency_converter_up.gain

# %%

# %%
f,ax = plt.subplots(1,1, figsize = (8,5))

for meas_id in meas_ids:
    # datas[meas_id].S.plot(ax=ax, xscale='log', yscale='log', x = "freq", lw = 0,marker = 'o', label=f'{meas_id} {gains[meas_id]}')
    ax.errorbar(datas[meas_id].freq, datas[meas_id].S.isel(qubit = 0), yerr = datas[meas_id].S_error.isel(qubit = 0), 
                fmt='o', label=f'{gains[meas_id]}', lw = 1, ls = '--')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('S [rad s$^{-1}$]')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e4, 1e8)
ax.set_ylim(5e3, 5e5)
ax.grid()
ax.legend()

# %%
meas_ids = [2237,2242,2245,2247, 2240]

datas = {}
node_parameters = {}
machines = {}
gains = {}  

for meas_id in meas_ids:
    datas[meas_id], machines[meas_id], node_parameters[meas_id] = load_dataset(meas_id, "noise_spectrum")
    gains[meas_id] = machines[meas_id].qubits[node_parameters[meas_id]['initial_parameters']['qubits'][0]].resonator.opx_output.full_scale_power_dbm

# %%

# %%
f,ax = plt.subplots(1,1, figsize = (8,5))

for meas_id in meas_ids:
    # datas[meas_id].S.plot(ax=ax, xscale='log', yscale='log', x = "freq", lw = 0,marker = 'o', label=f'{meas_id} {gains[meas_id]}')
    ax.errorbar(datas[meas_id].freq, datas[meas_id].S.isel(qubit = 0), yerr = datas[meas_id].S_error.isel(qubit = 0), 
                fmt='o', label=f'{gains[meas_id]} dBm', lw = 1, ls = '--')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('S [rad s$^{-1}$]')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(4.5e5, 1e8)
ax.set_ylim(9e3, 4e5)
ax.grid()
ax.legend()

# %%
meas_ids = [2304,2310, 2316]

datas = {}
node_parameters = {}
machines = {}
IF = {}  

for meas_id in meas_ids:
    datas[meas_id], machines[meas_id], node_parameters[meas_id] = load_dataset(meas_id, "noise_spectrum")
    IF[meas_id] = machines[meas_id].qubits[node_parameters[meas_id]['initial_parameters']['qubits'][0]].resonator.intermediate_frequency

# %%

# %%
f,ax = plt.subplots(1,1, figsize = (8,5))

for meas_id in meas_ids:
    # datas[meas_id].S.plot(ax=ax, xscale='log', yscale='log', x = "freq", lw = 0,marker = 'o', label=f'{meas_id} {gains[meas_id]}')
    ax.errorbar(datas[meas_id].freq, datas[meas_id].S.isel(qubit = 0), yerr = datas[meas_id].S_error.isel(qubit = 0), 
                fmt='o', label=f'{IF[meas_id]/1e6:.1f} MHz', lw = 1, ls = '--')
ax.set_xlabel('Frequency [Hz]')
ax.set_ylabel('S [rad s$^{-1}$]')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(6e4, 1e8)
ax.set_ylim(9e3, 2e6)
ax.grid()
ax.legend()

# %%
machines[meas_id].qubits[node_parameters[meas_id]['initial_parameters']['qubits'][0]].resonator
# Out:
# ReadoutResonatorMW(depletion_time=2500, frequency_bare=None, f_01=None, f_12=None, confusion_matrix=[[0.8785, 0.1215], [0.1245, 0.8755]], gef_centers=None, gef_confusion_matrix=None, operations={'readout': SquareReadoutPulse(length=1500, id=None, digital_marker='ON', amplitude=0.0009123456, axis_angle=None, threshold=-0.00013987701679937315, rus_exit_threshold=-0.00039641058843468865, integration_weights=None, integration_weights_angle=-57.87305541068674), 'const': SquarePulse(length=100, id=None, digital_marker=None, amplitude=0.125, axis_angle=None)}, id=None, digital_outputs={}, sticky=None, intermediate_frequency=-197107812.0, thread=None, opx_input=MWFEMAnalogInputPort(controller_id='con1', fem_id=2, port_id=2, band=3, downconverter_frequency=7350000000, sampling_rate=1000000000.0, shareable=False), time_of_flight=264, smearing=0, LO_frequency=7350000000, RF_frequency=7152892188.0, opx_output=MWFEMAnalogOutputPort(controller_id='con1', fem_id=2, port_id=8, band=3, upconverter_frequency=7350000000, upconverters=None, delay=0, shareable=False, sampling_rate=1000000000.0, full_scale_power_dbm=7), upconverter=1)

# %%
7.35-0.195
# Out:
# 7.154999999999999
